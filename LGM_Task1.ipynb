# %% [markdown]
# #Iris Flowers Classification ML Project

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib as mlp
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv("Iris.csv")

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
data.shape #Gives no. of rows and columns
# Out:
# (150, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
data["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# #Data Cleaning

# %%
df = data.drop(['Id'], axis=1) #removing Id column as we don't need it further.
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# Data Visualization

# %%
sns.set(style="dark")

sns.pairplot(df, hue="Species")
plt.show()

# %%
sns.heatmap(df.corr(), cmap='YlGnBu',annot=True, fmt=".2f")
# Out:
# <ipython-input-13-2d346dcba2f1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap='YlGnBu',annot=True, fmt=".2f")
# <Axes: >

# %%
df.corr()
# Out:
# <ipython-input-14-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
#Relationship between SepalLengthCm	and Species
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Species', y='SepalLengthCm')
plt.title('Sepal Length by Species')
plt.show()

# %%
#Relationship between SepalWidthCm and Species
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Species', y='SepalWidthCm')
plt.title('Sepal Width by Species')
plt.show()

# %%
#Relationship between PetalLengthCm	and Species
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Species', y='PetalLengthCm')
plt.title('Petal Length by Species')
plt.show()

# %%
#Relationship between PetalWidthCm and Species
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Species', y='PetalWidthCm')
plt.title('Petal Width by Species')
plt.show()

# %% [markdown]
# #Statisctics

# %%
#See exact numbers
make_total = df.pivot_table("SepalLengthCm",index=['Species'],aggfunc='mean')
spec = make_total.sort_values(by='Species',ascending=False)
print(spec)
# Out:
#                  SepalLengthCm
# Species
# Iris-virginica           6.588
# Iris-versicolor          5.936
# Iris-setosa              5.006

# %%
make_total = df.pivot_table("SepalWidthCm",index=['Species'],aggfunc='mean')
spec = make_total.sort_values(by='Species',ascending=False)
print(spec)
# Out:
#                  SepalWidthCm
# Species
# Iris-virginica          2.974
# Iris-versicolor         2.770
# Iris-setosa             3.418

# %%
make_total = df.pivot_table("PetalLengthCm",index=['Species'],aggfunc='mean')
spec = make_total.sort_values(by='Species',ascending=False)
print(spec)
# Out:
#                  PetalLengthCm
# Species
# Iris-virginica           5.552
# Iris-versicolor          4.260
# Iris-setosa              1.464

# %%
make_total = df.pivot_table("PetalWidthCm",index=['Species'],aggfunc='mean')
spec = make_total.sort_values(by='Species',ascending=False)
print(spec)
# Out:
#                  PetalWidthCm
# Species
# Iris-virginica          2.026
# Iris-versicolor         1.326
# Iris-setosa             0.244

# %% [markdown]
# #Separating Features and Target

# %%
x = df.drop(['Species'], axis=1)
y = df["Species"]

# %% [markdown]
# #Model Training

# %%
# Spliting the data into training and testing dataset.
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state = 0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120,)
# (30,)

# %%
x_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 137            6.4           3.1            5.5           1.8
# 84             5.4           3.0            4.5           1.5
# 27             5.2           3.5            1.5           0.2
# 127            6.1           3.0            4.9           1.8
# 132            6.4           2.8            5.6           2.2
# ..             ...           ...            ...           ...
# 9              4.9           3.1            1.5           0.1
# 103            6.3           2.9            5.6           1.8
# 67             5.8           2.7            4.1           1.0
# 117            7.7           3.8            6.7           2.2
# 47             4.6           3.2            1.4           0.2
#
# [120 rows x 4 columns]

# %%
y_train
# Out:
# 137     Iris-virginica
# 84     Iris-versicolor
# 27         Iris-setosa
# 127     Iris-virginica
# 132     Iris-virginica
#             ...
# 9          Iris-setosa
# 103     Iris-virginica
# 67     Iris-versicolor
# 117     Iris-virginica
# 47         Iris-setosa
# Name: Species, Length: 120, dtype: object

# %%
x_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 114            5.8           2.8            5.1           2.4
# 62             6.0           2.2            4.0           1.0
# 33             5.5           4.2            1.4           0.2
# 107            7.3           2.9            6.3           1.8
# 7              5.0           3.4            1.5           0.2
# 100            6.3           3.3            6.0           2.5
# 40             5.0           3.5            1.3           0.3
# 86             6.7           3.1            4.7           1.5
# 76             6.8           2.8            4.8           1.4
# 71             6.1           2.8            4.0           1.3
# 134            6.1           2.6            5.6           1.4
# 51             6.4           3.2            4.5           1.5
# 73             6.1           2.8            4.7           1.2
# 54             6.5           2.8            4.6           1.5
# ...

# %%
y_test
# Out:
# 114     Iris-virginica
# 62     Iris-versicolor
# 33         Iris-setosa
# 107     Iris-virginica
# 7          Iris-setosa
# 100     Iris-virginica
# 40         Iris-setosa
# 86     Iris-versicolor
# 76     Iris-versicolor
# 71     Iris-versicolor
# 134     Iris-virginica
# 51     Iris-versicolor
# 73     Iris-versicolor
# 54     Iris-versicolor
# 63     Iris-versicolor
# 37         Iris-setosa
# 78     Iris-versicolor
# 90     Iris-versicolor
# 45         Iris-setosa
# 16         Iris-setosa
# 121     Iris-virginica
# 66     Iris-versicolor
# 24         Iris-setosa
# 8          Iris-setosa
# 126     Iris-virginica
# 22         Iris-setosa
# 44         Iris-setosa
# 97     Iris-versicolor
# 93     Iris-versicolor
# 26         Iris-setosa
# Name: Species, dtype: object

# %% [markdown]
# #Logistic Regression

# %%
# Loading the Regressor Model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
#Fitting the model
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# #Model Evaluation

# %%
#PREDICT THE OUTPUT
y_pred = model.predict(x_test)
y_pred #PREDCITED VALUES
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa'], dtype=object)

# %%
y_test #ACTUAL VALUES
# Out:
# 114     Iris-virginica
# 62     Iris-versicolor
# 33         Iris-setosa
# 107     Iris-virginica
# 7          Iris-setosa
# 100     Iris-virginica
# 40         Iris-setosa
# 86     Iris-versicolor
# 76     Iris-versicolor
# 71     Iris-versicolor
# 134     Iris-virginica
# 51     Iris-versicolor
# 73     Iris-versicolor
# 54     Iris-versicolor
# 63     Iris-versicolor
# 37         Iris-setosa
# 78     Iris-versicolor
# 90     Iris-versicolor
# 45         Iris-setosa
# 16         Iris-setosa
# 121     Iris-virginica
# 66     Iris-versicolor
# 24         Iris-setosa
# 8          Iris-setosa
# 126     Iris-virginica
# 22         Iris-setosa
# 44         Iris-setosa
# 97     Iris-versicolor
# 93     Iris-versicolor
# 26         Iris-setosa
# Name: Species, dtype: object

# %% [markdown]
# #Accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)* 100
# Out:
# 100.0
